# %% [markdown]
# Esse jupyter notebook apresenta uma ánalise dos dados de doenças cardiacas de um desafio da CybeLabs(https://github.com/cyberlabsai/desafios-machine-learning).
#
# Primeiro foi feito um estudo sobre como uma doença cardíaca é detectada pelos médicos e quais são os exames necessarios para isso.Sabemos que o nivel de colesterol , a frequencia dos batimentos e numeros de veias principais são fatores importantes para determinar se uma pessoa tem a tendencia de ter uma doença cardiovascular
#
# Foi treinado 4 modelos de machine learning nesse notebook(Naive Bayes,Logistic Regression,Random Forest e XGBoost Classifier)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

#Models
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB

import xgboost as xgb
from xgboost import XGBClassifier

# %%
# age - age in years
# trestbps - resting blood pressure (in mm Hg on admission to the hospital)
# chol - serum cholestoral in mg/dl
# restecg - resting electrocardiographic results
# thalach - maximum heart rate achieved
# oldpeak - ST depression induced by exercise relative to rest

# fbs - (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# sex - (1 = male; 0 = female)
# exang - exercise induced angina (1 = yes; 0 = no)
# ca - number of major vessels (0-3) colored by flourosopy ; Value is null

# cp - chest pain type(Value 0: typical angina, Value 1: atypical angina, Value 2: non-anginal pain, Value 3: asymptomatic)
# the slope of the peak exercise ST segment (Value 0: upsloping, Value 1: flat, Value 2: downsloping)
# thal - 0 = null ;1= normal; 2 = fixed defect; 3 = reversable defect


# target - have disease or not (1=yes, 0=no)

# %% [markdown]
# # Import the Data

# %%
df = pd.read_csv('Mission_Prediction_Dataset.csv')

# %%
df.columns = ['age','sex','cp','trestbps','chol','fbs','restecg'
              ,'thalach','exang','oldpeak','slope','ca','thal','target']

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# # Preprocessing

# %%
#Data Cleaning ca = 4 ou thal = 0  sao valores nulos
df = df[(df['ca']!= 4) & (df['thal']!= 0)]

df['cp'].loc[df['cp'] == 0] = 'typical angina'
df['cp'].loc[df['cp'] == 1] = 'atypical angina'
df['cp'].loc[df['cp'] == 2] = 'non-anginal pain'
df['cp'].loc[df['cp'] == 3] = 'asymptomatic'

df['slope'].loc[df['slope'] == 0] = 'upsloping'
df['slope'].loc[df['slope'] == 1] = 'flat'
df['slope'].loc[df['slope'] == 2] = 'downsloping'

df['thal'].loc[df['thal'] == 1] = 'normal'
df['thal'].loc[df['thal'] == 2] = 'fixed defect'
df['thal'].loc[df['thal'] == 3] = 'reversable defect'
# Out:
# /Users/alexandremaxinsang/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df = pd.get_dummies(df)

# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 296 entries, 0 to 302
# Data columns (total 21 columns):
# age                       296 non-null int64
# sex                       296 non-null int64
# trestbps                  296 non-null int64
# chol                      296 non-null int64
# fbs                       296 non-null int64
# restecg                   296 non-null int64
# thalach                   296 non-null int64
# exang                     296 non-null int64
# oldpeak                   296 non-null float64
# ca                        296 non-null int64
# target                    296 non-null int64
# cp_asymptomatic           296 non-null uint8
# cp_atypical angina        296 non-null uint8
# cp_non-anginal pain       296 non-null uint8
# cp_typical angina         296 non-null uint8
# slope_downsloping         296 non-null uint8
# slope_flat                296 non-null uint8
# slope_upsloping           296 non-null uint8
# thal_fixed defect         296 non-null uint8
# thal_normal               296 non-null uint8
# thal_reversable defect    296 non-null uint8
# dtypes: float64(1), int64(10), uint8(10)
# memory usage: 30.6 KB

# %% [markdown]
# No missing data

# %%
df.describe()
# Out:
#               age         sex   trestbps        chol        fbs     restecg  \
# count  296.000000  296.000000  296.00000  296.000000  296.00000  296.000000
# mean    54.523649    0.679054  131.60473  247.155405    0.14527    0.523649
# std      9.059471    0.467631   17.72662   51.977011    0.35297    0.526692
# min     29.000000    0.000000   94.00000  126.000000    0.00000    0.000000
# 25%     48.000000    0.000000  120.00000  211.000000    0.00000    0.000000
# 50%     56.000000    1.000000  130.00000  242.500000    0.00000    1.000000
# 75%     61.000000    1.000000  140.00000  275.250000    0.00000    1.000000
# max     77.000000    1.000000  200.00000  564.000000    1.00000    2.000000
#
#           thalach       exang     oldpeak          ca  ...  cp_asymptomatic  \
# count  296.000000  296.000000  296.000000  296.000000  ...       296.000000
# mean   149.560811    0.327703    1.059122    0.679054  ...         0.077703
# std     22.970792    0.470171    1.166474    0.939726  ...         0.268157
# min     71.000000    0.000000    0.000000    0.000000  ...         0.000000
# 25%    133.000000    0.000000    0.000000    0.000000  ...         0.000000
# 50%    152.500000    0.000000    0.800000    0.000000  ...         0.000000
# 75%    166.000000    1.000000    1.650000    1.000000  ...         0.000000
# max    202.000000    1.000000    6.200000    3.000000  ...         1.000000
#
#        cp_atypical angina  cp_non-anginal pain  cp_typical angina  \
# count          296.000000           296.000000         296.000000
# mean             0.165541             0.280405           0.476351
# std              0.372297             0.449958           0.500286
# min              0.000000             0.000000           0.000000
# 25%              0.000000             0.000000           0.000000
# 50%              0.000000             0.000000           0.000000
# 75%              0.000000             1.000000           1.000000
# max              1.000000             1.000000           1.000000
#
#        slope_downsloping  slope_flat  slope_upsloping  thal_fixed defect  \
# count         296.000000  296.000000       296.000000         296.000000
# mean            0.466216    0.462838         0.070946           0.550676
# std             0.499702    0.499461         0.257169           0.498268
# min             0.000000    0.000000         0.000000           0.000000
# 25%             0.000000    0.000000         0.000000           0.000000
# 50%             0.000000    0.000000         0.000000           1.000000
# 75%             1.000000    1.000000         0.000000           1.000000
# max             1.000000    1.000000         1.000000           1.000000
#
#        thal_normal  thal_reversable defect
# count   296.000000              296.000000
# mean      0.060811                0.388514
# std       0.239388                0.488238
# min       0.000000                0.000000
# 25%       0.000000                0.000000
# 50%       0.000000                0.000000
# 75%       0.000000                1.000000
# max       1.000000                1.000000
#
# [8 rows x 21 columns]

# %%
corr = df.corr('spearman')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col1 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col2 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col3 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col4 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col5 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col6 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col7 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col8 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col9 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col10 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col11 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col12 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col13 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col14 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col15 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col16 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col17 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col18 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col19 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row0_col20 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col0 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col2 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col4 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col5 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col6 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col7 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col8 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col9 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col10 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col11 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col12 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col13 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col14 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col15 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col16 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col17 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col18 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col19 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row1_col20 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col0 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col1 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col3 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col4 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col5 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col6 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col7 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col8 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col9 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col10 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col11 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col12 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col13 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col14 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col15 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col16 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_61878f44_6407_11ea_b943_3c15c2c47a18row2_col17 {
#             background-color:  #97b8ff;

# %% [markdown]
# Podemos percerber que o target NAO tem correlação com fbs,cp_asymptomatic,slope_upsloping

# %%
sns.countplot(x = "target", data=df)
plt.show()

# %%
pd.crosstab(df.age,df.target).plot(kind="bar",figsize=(20,10))
plt.title('Heart Disease Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Modeling

# %% [markdown]
# A evaluação é feita pela a metrica acurácia

# %% [markdown]
# ## Splitting the data

# %%
target_name = 'target'
data_target = df[target_name]
data = df.drop([target_name], axis=1)

# %%
train_x, test_x, train_y, test_y = train_test_split(data, data_target, test_size= 0.3, random_state=0)

# %% [markdown]
# ## Naive Bayes

# %%
gaussian = GaussianNB()
gaussian.fit(train_x, train_y)
acc_gaussian = round(gaussian.score(train_x, train_y) * 100, 2)
acc_gaussian
# Out:
# 86.96

# %%
acc_test_gaussian = round(gaussian.score(test_x, test_y) * 100, 2)
acc_test_gaussian
# Out:
# 84.27

# %%
predicted = gaussian.predict(test_x)
print(metrics.classification_report(test_y, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84        45
#            1       0.83      0.86      0.84        44
#
#    micro avg       0.84      0.84      0.84        89
#    macro avg       0.84      0.84      0.84        89
# weighted avg       0.84      0.84      0.84        89

# %% [markdown]
# ## Logistic Regression

# %%
# Logistic Regression

logreg = LogisticRegression()
logreg.fit(train_x, train_y)
acc_log = round(logreg.score(train_x, train_y) * 100, 2)
acc_log
# Out:
# /Users/alexandremaxinsang/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 89.86

# %%
acc_test_log = round(logreg.score(test_x, test_y) * 100, 2)
acc_test_log
# Out:
# 84.27

# %%
predicted =logreg.predict(test_x)

# %%
print(metrics.classification_report(test_y, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.83        45
#            1       0.80      0.91      0.85        44
#
#    micro avg       0.84      0.84      0.84        89
#    macro avg       0.85      0.84      0.84        89
# weighted avg       0.85      0.84      0.84        89

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Hyperparameter Turning

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 500, num = 50)]

# Create the random grid
random_grid = {'n_estimators': n_estimators}

# %%
random_forest = GridSearchCV(estimator = RandomForestClassifier(), 
                             param_grid = random_grid, cv = 5)
random_forest.fit(train_x, train_y)
acc_random_forest = round(random_forest.score(train_x, train_y) * 100, 2)
print(acc_random_forest,random_forest.best_params_)
# Out:
# /Users/alexandremaxinsang/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 100.0 {'n_estimators': 230}

# %%
acc_test_random_forest = round(random_forest.score(test_x, test_y) * 100, 2)
acc_test_random_forest
# Out:
# 83.15

# %%
predicted = random_forest.predict(test_x)

# %%
features = train_x.columns

# %%
importances = random_forest.best_estimator_.feature_importances_
indices = np.argsort(importances)

# %%
plt.title('Feature Importances')

plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])

plt.xlabel('Relative Importance')
plt.show()

# %%
print(metrics.classification_report(test_y, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82        45
#            1       0.80      0.89      0.84        44
#
#    micro avg       0.83      0.83      0.83        89
#    macro avg       0.84      0.83      0.83        89
# weighted avg       0.84      0.83      0.83        89

# %% [markdown]
# ## XGBoost Classifier

# %%
XGB_Classifier = XGBClassifier()
XGB_Classifier.fit(train_x, train_y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#        subsample=1, verbosity=1)

# %%
acc_test_xgbclassifier = round(XGB_Classifier.score(test_x, test_y) * 100, 2)
acc_test_xgbclassifier
# Out:
# 82.02

# %%
predicted = XGB_Classifier.predict(test_x)

# %%
fig =  plt.figure(figsize = (15,15))
xgb.plot_importance(XGB_Classifier,height =0.5)
plt.show();
plt.close()

# %%
print(metrics.classification_report(test_y, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81        45
#            1       0.78      0.89      0.83        44
#
#    micro avg       0.82      0.82      0.82        89
#    macro avg       0.83      0.82      0.82        89
# weighted avg       0.83      0.82      0.82        89

# %% [markdown]
# # Conclusion

# %% [markdown]
# Verificamos que as features thal,thalach,cp e ca são features bem importantes para o nosso modelo.
