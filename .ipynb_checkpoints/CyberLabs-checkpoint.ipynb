# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Models
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier

# %% [markdown]
# # Import the Data

# %%
df = pd.read_csv('Mission_Prediction_Dataset.csv')

# %%
df.columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','target']

# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %% [markdown]
# No missing data

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
corr = df.corr('spearman')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col2 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col3 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col4 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col5 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col6 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col7 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col8 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col9 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col10 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col11 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col12 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row0_col13 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col0 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col2 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col3 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col4 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col5 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col6 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col7 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col8 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col9 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col10 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col11 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col12 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row1_col13 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col0 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col1 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col3 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col4 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col5 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col6 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col7 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col8 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col9 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col10 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col11 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col12 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row2_col13 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col0 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col1 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col2 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col4 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col5 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col6 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col7 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col8 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col9 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col10 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col11 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col12 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row3_col13 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row4_col0 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row4_col1 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row4_col2 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_e6a61f44_62c0_11ea_996e_3c15c2c47a18row4_col3 {
#             background-color:  #84a7fc;
#             colo

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Splitting the data

# %%
target_name = 'target'
data_target = df[target_name]
data = df.drop([target_name], axis=1)

# %%
train_x, test_x, train_y, test_y = train_test_split(data, data_target, test_size= 0.3, random_state=0)

# %% [markdown]
# ## Naive Bayes

# %%
gaussian = GaussianNB()
gaussian.fit(train_x, train_y)
acc_gaussian = round(gaussian.score(train_x, train_y) * 100, 2)
acc_gaussian
# Out:
# 84.43

# %%
acc_test_gaussian = round(gaussian.score(test_x, test_y) * 100, 2)
acc_test_gaussian
# Out:
# 80.22

# %% [markdown]
# ## Logistic Regression

# %%
# Logistic Regression

logreg = LogisticRegression()
logreg.fit(train_x, train_y)
acc_log = round(logreg.score(train_x, train_y) * 100, 2)
acc_log
# Out:
# /Users/alexandremaxinsang/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 85.85

# %%
acc_test_log = round(logreg.score(test_x, test_y) * 100, 2)
acc_test_log
# Out:
# 81.32

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Hyperparameter Turning

# %%
random_forest = GridSearchCV(estimator=RandomForestClassifier(), 
                             param_grid = {'n_estimators': [25,50,100,150,200]}, cv=5)
random_forest.fit(train_x, train_y)
acc_random_forest = round(random_forest.score(train_x, train_y) * 100, 2)
print(acc_random_forest,random_forest.best_params_)
# Out:
# 100.0 {'n_estimators': 100}
# /Users/alexandremaxinsang/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
acc_test_random_forest = round(random_forest.score(test_x, test_y) * 100, 2)
acc_test_random_forest
# Out:
# 82.42

# %%
features = train_x.columns

# %%
importances = random_forest.best_estimator_.feature_importances_
indices = np.argsort(importances)

# %%
plt.title('Feature Importances')

plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])

plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# ## XGBoost Classifier

# %%
XGB_Classifier = XGBClassifier()
XGB_Classifier.fit(train_x, train_y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#        subsample=1, verbosity=1)

# %%
acc_test_xgbclassifier = round(XGB_Classifier.score(test_x, test_y) * 100, 2)
acc_test_xgbclassifier
# Out:
# 80.22
